# %% [markdown]
# Problem Statement: Design a software for a bank. The software should have options such as cash withdrawal, cash credit, and change password. The software should provide the required output according to the user input. Hint: Use if...else statements and functions .
# Steps to Perform:
# 1. Declare the variables
# 2. Create a function to perform the functions (withdrawal, cash credit, and change password)
# 3. Use if...else statement to provide the required output.

# %%
## BANK SOFTWERE
#This project is a simple Bank Software in Python. It performs cash withdrawal, cash credit, and password change operations using functions.
#The program uses global variables to store balance and password, and if-else statements are 
#used to validate user inputs and perform the selected banking operation.


password = 1234

password = int(input("enter your login password"))

if password == password:
   print('login successfully')
else:
    print('invalid password')

def change_password(old_password, new_password):
    global password

    if old_password == password:
        password != new_password
        print("Login successfully")
        print("Password changing successfully")
        print("New password:", new_password)
    else:
        print("Invalid old password")

old_password = int(input("Enter old password: "))
new_password = int(input("Enter new password: "))

change_password(old_password, new_password)

change_password(old_password, new_password)
#withdrawal
password = 1234
balance = 20000.6
amount=float(input('Enter amount:'))

def withdrawal(amount):
    global balance #we can modify the balance
    if amount <= balance:
      balance = balance - amount
      print('available balance:', balance)
    else:
      print('check your balance')

withdrawal(amount)

#cash credit
balance = 20000
amount = int(input('Enter your amount:'))
def cash_credit(amount):
    global balance
    balance = balance + amount 
    print('available balance:',balance)

cash_credit(amount)

print("1.cash withdrawal")
print("2.cash credit") 
print("3.change password")

select = int(input("Select you want to do"))
if select == 1:
                withdrawal(amount)
elif select == 2:
                cash_credit(amount)
elif select == 3:
                change_password(old_password,new_password)
                print('new password:',password)
else:
                print('Eroor')
# Out:
# enter your login password 1234
# login successfully
# Enter old password:  1234
# Enter new password:  9090
# Login successfully
# Password changing successfully
# New password: 9090
# Login successfully
# Password changing successfully
# New password: 9090
# Enter amount: 500
# available balance: 19500.6
# Enter your amount: 800
# available balance: 20800
# 1.cash withdrawal
# 2.cash credit
# 3.change password
# Select you want to do 2
# available balance: 21600
